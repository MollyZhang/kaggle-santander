# %%
import pandas as pd
from sklearn.cross_validation import train_test_split

# %% [markdown]
# ### trainReduced.csv has redundant fields removed, and all data are scaled to Z-scores (standard deviates from mean)

# %%
df = pd.read_csv("../../data/trainReduced.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        ID      var3     var15  imp_ent_var16_ult1  \
# 0           1 -1.735031  0.039074 -0.788243           -0.053388
# 1           2 -1.734986  0.039074  0.060752           -0.053388
# 2           3 -1.734963  0.039074 -0.788243           -0.053388
# 3           4 -1.734871  0.039074  0.292296           -0.053388
# 4           5 -1.734826  0.039074  0.446659           -0.053388
#
#    imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  \
# 0                -0.213262                -0.218812                -0.038206
# 1                -0.213262                -0.218812                -0.038206
# 2                -0.213262                -0.218812                -0.038206
# 3                 0.361424                 0.138157                -0.038206
# 4                -0.213262                -0.218812                -0.038206
#
#    imp_op_var40_comer_ult3  imp_op_var40_efect_ult1    ...     \
# ...

# %%
# Remove column "Unnamed: 0" (artifact of data write in R)
df = df.drop(df.columns[[0]], axis = 1)

# %%
df.head()
# Out:
#          ID      var3     var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 0 -1.735031  0.039074 -0.788243           -0.053388                -0.213262
# 1 -1.734986  0.039074  0.060752           -0.053388                -0.213262
# 2 -1.734963  0.039074 -0.788243           -0.053388                -0.213262
# 3 -1.734871  0.039074  0.292296           -0.053388                 0.361424
# 4 -1.734826  0.039074  0.446659           -0.053388                -0.213262
#
#    imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# 0                -0.218812                -0.038206                -0.042102
# 1                -0.218812                -0.038206                -0.042102
# 2                -0.218812                -0.038206                -0.042102
# 3                 0.138157                -0.038206                -0.042102
# 4                -0.218812                -0.038206                -0.042102
#
# ...

# %%
# Replace IDs with int vals
len(df)
# Out:
# 76020

# %%
df.ix[:, 0] = range(1, 76021)

# %%
df.head()
# Out:
#    ID      var3     var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 0   1  0.039074 -0.788243           -0.053388                -0.213262
# 1   2  0.039074  0.060752           -0.053388                -0.213262
# 2   3  0.039074 -0.788243           -0.053388                -0.213262
# 3   4  0.039074  0.292296           -0.053388                 0.361424
# 4   5  0.039074  0.446659           -0.053388                -0.213262
#
#    imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# 0                -0.218812                -0.038206                -0.042102
# 1                -0.218812                -0.038206                -0.042102
# 2                -0.218812                -0.038206                -0.042102
# 3                 0.138157                -0.038206                -0.042102
# 4                -0.218812                -0.038206                -0.042102
#
#    imp_op_var40_efect_ult1  imp_op_var40_efect_ult3    ...     \
# ...

# %% [markdown]
# # Split df into test and train for initial model building/testing

# %%
# First split out TARGET column, to confrom to sklearn style
y = df.ix[:, 'TARGET']

# %%
X = df.drop('TARGET', axis = 1)

# %%
(X.columns.values)
# Out:
# array(['ID', 'var3', 'var15', 'imp_ent_var16_ult1',
#        'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3',
#        'imp_op_var40_comer_ult1', 'imp_op_var40_comer_ult3',
#        'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3',
#        'imp_op_var40_ult1', 'imp_op_var41_efect_ult1',
#        'imp_op_var41_efect_ult3', 'imp_op_var41_ult1',
#        'imp_sal_var16_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0',
#        'ind_var5', 'ind_var6_0', 'ind_var6', 'ind_var8_0', 'ind_var8',
#        'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0',
#        'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo',
#        'ind_var13_medio_0', 'ind_var13', 'ind_var14_0', 'ind_var14',
#        'ind_var17_0', 'ind_var17', 'ind_var18_0', 'ind_var19',
#        'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24',
#        'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var25_0',
#        'ind_var30_0', 'ind_var30', 'ind_var31_0', 'ind_var31',
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1)
